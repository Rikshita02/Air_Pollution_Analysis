# %% [markdown]
# # Air Quality Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('C58_Linear_reg_AirQualityUCI.csv', sep=';')
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %% [markdown]
# ## Data Preprocessing

# %%
df.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  9357.000000   9357.000000  9357.000000          0.0          0.0
# mean     58.148873   1391.479641   975.072032          NaN          NaN
# std     126.940455    467.210125   456.938184          NaN          NaN
# min    -200.000000   -200.000000  -200.000000          NaN          NaN
# 25%      53.000000   1185.000000   700.000000          NaN          NaN
# 50%      96.000000   1446.000000   942.000000          NaN          NaN
# 75%     133.000000   1662.000000  1255.000000          NaN          NaN
# max     340.000000   2775.000000  2523.000000          NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ## 1) Drop Null columns

# %%
df = df.drop(columns=['Unnamed: 15', 'Unnamed: 16'], axis = 1)

# %% [markdown]
# ## 2) Removing Missing Values

# %%
df.isnull().sum()
# Out:
# Date             114
# Time             114
# CO(GT)           114
# PT08.S1(CO)      114
# NMHC(GT)         114
# C6H6(GT)         114
# PT08.S2(NMHC)    114
# NOx(GT)          114
# PT08.S3(NOx)     114
# NO2(GT)          114
# PT08.S4(NO2)     114
# PT08.S5(O3)      114
# T                114
# RH               114
# AH               114
# dtype: int64

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# 4  0,7888

# %%
df[df['Date'].isnull() == True]
# Out:
#      Date Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 9357  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9358  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9359  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9360  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9361  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# ...   ...  ...    ...          ...       ...      ...            ...      ...
# 9466  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9467  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9468  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9469  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
# 9470  NaN  NaN    NaN          NaN       NaN      NaN            NaN      NaN
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    T   RH   AH
# 9357           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9358           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9359           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9360           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9361           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# ...            ...      ...           ...          ...  ...  ...  ...
# 9466           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9467           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9468           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9469           NaN      NaN           NaN          NaN  NaN  NaN  NaN
# 9470           NaN      NaN           NaN          NaN  NaN  NaN  NaN
#
# [114 rows x 15 columns]

# %% [markdown]
# ## 3) Drop all null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# ## 4) Parsing datetime Values

# %%
dt_series = pd.Series(data = [item.split('/')[2] + '-' + item.split('/')[1] + '-' + item.split('/')[0] for item in df['Date']], index = df.index) + ' ' + pd.Series(data = [str(item).replace('.', ':') for item in df['Time']], index = df.index)
dt_series = pd.to_datetime(dt_series)
dt_series
# Out:
# 0      2004-03-10 18:00:00
# 1      2004-03-10 19:00:00
# 2      2004-03-10 20:00:00
# 3      2004-03-10 21:00:00
# 4      2004-03-10 22:00:00
#                ...
# 9352   2005-04-04 10:00:00
# 9353   2005-04-04 11:00:00
# 9354   2005-04-04 12:00:00
# 9355   2005-04-04 13:00:00
# 9356   2005-04-04 14:00:00
# Length: 9357, dtype: datetime64[ns]

# %%
df = df.drop(columns = ['Date', 'Time'], axis = 1)
# df.insert(loc = 0, column = 'DateTime', value = dt_series)

date_series = dt_series.dt.date
time_series = dt_series.dt.time
year_series = dt_series.dt.year
month_series = dt_series.dt.month
day_series = dt_series.dt.day
day_name_series = dt_series.dt.day_name()

df.insert(loc = 0, column = 'Date', value = date_series)
df.insert(loc = 1, column = 'Time', value = time_series)

df['Year'] = year_series
df['Month'] = month_series
df['Day'] = day_series
df['Day Name'] = day_name_series

df = df.sort_values(by = 'Date')

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  2004-03-10  18:00:00    2,6       1360.0     150.0     11,9         1046.0
# 1  2004-03-10  19:00:00      2       1292.0     112.0      9,4          955.0
# 2  2004-03-10  20:00:00    2,2       1402.0      88.0      9,0          939.0
# 3  2004-03-10  21:00:00    2,2       1376.0      80.0      9,2          948.0
# 4  2004-03-10  22:00:00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Year  Month  Day   Day Name
# 0  0,7578  2004      3   10  Wednesday
# 1  0,7255  2004      3   10  Wednesday
# 2  0,7502  2004      3   10  Wednesday
# 3  0,7867  2004      3   10  Wednesday
# 4  0,7888  2004      3   10  Wednesday

# %% [markdown]
# ## 5) Comma to Period i.e. ( ',' to '.')

# %%
def comma_to_period(series):
    new_series = pd.Series(data=[float(str(item).replace(',', '.')) for item in series], index = df.index)
    return new_series

# %%
cols_to_correct = ['CO(GT)', 'C6H6(GT)', 'T', 'RH', 'AH']
for col in cols_to_correct:
    df[col] = comma_to_period(df[col])

# %% [markdown]
# ## 6) Garbage data Inspection

# %% [markdown]
# ### Replacing garbage values (-ve) by median or mean

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      50.000000    637.000000    53.000000   1185.000000   700.000000
# 50%     141.000000    794.000000    96.000000   1446.000000   942.000000
# 75%     284.000000    960.000000   133.000000   1662.000000  1255.000000
# max    1479.000000   2683.000000   340.000000   2775.000000  2523.000000
#
#                  T           RH           AH         Year        Month  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean      9.778305    39.485380    -6.837604  2004.240141     6.310356
# std      43.203623    51.216145    38.976670     0.427192     3.438160
# min    -200.000000  -200.000000  -200.000000  2004.000000     1.000000
# 25%      10.900000    34.100000     0.692300  2004.000000     3.000000
# 50%      17.200000    48.600000     0.976800  2004.000000     6.000000
# 75%      24.100000    61.900000     1.296200  2004.000000     9.000000
# max      44.600000    88.700000     2.231000  2005.000000    12.000000
#
#                Day
# count  9357.000000
# mean     15.876884
# std       8.808653
# min       1.000000
# 25%       8.000000
# 50%      16.000000
# 75%      23.000000
# max      31.000000

# %% [markdown]
# We observe there are negative values in most of the places in dataset

# %% [markdown]
# We will replace the negative values by the mean of the rest of the positive values to not "lessen" the dataset

# %%
neg_counts = [(col, df[df[col] == -200].shape[0]) for col in df.columns[2:-4]]
neg_counts
# Out:
# [('CO(GT)', 1683),
#  ('PT08.S1(CO)', 366),
#  ('NMHC(GT)', 8443),
#  ('C6H6(GT)', 366),
#  ('PT08.S2(NMHC)', 366),
#  ('NOx(GT)', 1639),
#  ('PT08.S3(NOx)', 366),
#  ('NO2(GT)', 1642),
#  ('PT08.S4(NO2)', 366),
#  ('PT08.S5(O3)', 366),
#  ('T', 366),
#  ('RH', 366),
#  ('AH', 366)]

# %%
neg_percent = [(col, round(df[df[col] == -200].shape[0] * 100/ df.shape[0], 2)) for col in df.columns[2:-4]]
neg_percent
# Out:
# [('CO(GT)', 17.99),
#  ('PT08.S1(CO)', 3.91),
#  ('NMHC(GT)', 90.23),
#  ('C6H6(GT)', 3.91),
#  ('PT08.S2(NMHC)', 3.91),
#  ('NOx(GT)', 17.52),
#  ('PT08.S3(NOx)', 3.91),
#  ('NO2(GT)', 17.55),
#  ('PT08.S4(NO2)', 3.91),
#  ('PT08.S5(O3)', 3.91),
#  ('T', 3.91),
#  ('RH', 3.91),
#  ('AH', 3.91)]

# %% [markdown]
# ## Garbage value Replacement

# %%
import warnings
warnings.filterwarnings('ignore')

for col in df.columns[2:-4]:
    median = df.loc[df[col] != -200, col].median()
    df[col] = df[col].replace(to_replace = -200, value = median)

# %%
df.tail()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9344  2005-04-04  02:00:00     0.5        912.0     150.0       1.5
# 9342  2005-04-04  00:00:00     0.9       1012.0     150.0       3.5
# 9355  2005-04-04  13:00:00     2.1       1003.0     150.0       9.5
# 9348  2005-04-04  06:00:00     1.1       1031.0     150.0       4.4
# 9356  2005-04-04  14:00:00     2.2       1071.0     150.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9344          544.0     69.0         959.0     55.0        1002.0
# 9342          683.0    117.0         801.0     93.0        1073.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9348          730.0    182.0         760.0     93.0        1129.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH  Year  Month  Day Day Name
# 9344        573.0  12.1  56.3  0.7927  2005      4    4   Monday
# 9342        816.0  14.2  51.4  0.8275  2005      4    4   Monday
# 9355        770.0  28.3  13.5  0.5139  2005      4    4   Monday
# 9348        905.0   9.5  63.1  0.7531  2005      4    4   Monday
# 9356        816.0  28.5  13.1  0.5028  2005      4    4   Monday

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean      2.089302  1098.392433   156.721599    10.009447     937.973923
# std       1.323024   212.911465    67.058156     7.311771     261.625561
# min       0.100000   647.000000     7.000000     0.100000     383.000000
# 25%       1.200000   941.000000   150.000000     4.600000     743.000000
# 50%       1.800000  1063.000000   150.000000     8.200000     909.000000
# 75%       2.600000  1221.000000   150.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    235.178903    834.339959   112.373303   1456.528054  1020.562894
# std     195.091025    251.808888    43.948519    339.370072   390.784960
# min       2.000000    322.000000     2.000000    551.000000   221.000000
# 25%     112.000000    666.000000    86.000000   1242.000000   742.000000
# 50%     180.000000    806.000000   109.000000   1463.000000   963.000000
# 75%     284.000000    960.000000   133.000000   1662.000000  1255.000000
# max    1479.000000   2683.000000   340.000000   2775.000000  2523.000000
#
#                  T           RH           AH         Year        Month  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean     18.297574    49.248509     1.024352  2004.240141     6.310356
# std       8.658221    16.974949     0.395878     0.427192     3.438160
# min      -1.900000     9.200000     0.184700  2004.000000     1.000000
# 25%      12.000000    36.600000     0.746100  2004.000000     3.000000
# 50%      17.800000    49.600000     0.995400  2004.000000     6.000000
# 75%      24.100000    61.900000     1.296200  2004.000000     9.000000
# max      44.600000    88.700000     2.231000  2005.000000    12.000000
#
#                Day
# count  9357.000000
# mean     15.876884
# std       8.808653
# min       1.000000
# 25%       8.000000
# 50%      16.000000
# 75%      23.000000
# max      31.000000

# %%
df.to_csv('clean_air_2.csv', index = False)
